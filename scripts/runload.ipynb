# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from notebookutils import mssparkutils
# Out:
# StatementMeta(, ac23228d-8797-418c-82b2-b98449a33865, 4, Finished, Available, Finished)

# %%
mssparkutils.fs.mount("abfss://ffba5c1d-6c17-4857-92b8-283135916ea3@onelake.dfs.fabric.microsoft.com/2f70d0d4-b2dd-4276-a27c-dd99afb07eed/Files","/Files")
# Out:
# StatementMeta(, ac23228d-8797-418c-82b2-b98449a33865, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, fff10405-5794-438d-9ca7-73c91e201e97)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, ac23228d-8797-418c-82b2-b98449a33865, 6, Finished, Available, Finished)
# '/synfs/notebook/ac23228d-8797-418c-82b2-b98449a33865/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/current/")
# Out:
# StatementMeta(, ac23228d-8797-418c-82b2-b98449a33865, 7, Finished, Available, Finished)

# %%
check_files
# Out:
# StatementMeta(, ac23228d-8797-418c-82b2-b98449a33865, 8, Finished, Available, Finished)
# [FileInfo(path=file:/synfs/notebook/ac23228d-8797-418c-82b2-b98449a33865/Files/current/Sales_04012023.xlsx, name=Sales_04012023.xlsx, size=535106)]

# %%
if check_files :
    mssparkutils.notebook.run("bronze_sales")
    mssparkutils.notebook.run("gold_customer")
    mssparkutils.notebook.run("gold_date")
    mssparkutils.notebook.run("Gold_OrderPriority")
    mssparkutils.notebook.run("gold_product")
    mssparkutils.notebook.run("gold_shipmode")
    mssparkutils.notebook.run("gold_orderreturn")
# Out:
# StatementMeta(, ac23228d-8797-418c-82b2-b98449a33865, 13, Finished, Available, Finished)
