# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, f790f2fe-ddd7-4750-8b7f-5998e646fcf1, 3, Finished, Available, Finished)

# %%
# %%sql
# create table if not EXISTS Project_Lakehouse.gold_date
# (
# BusinessDate Date,
# Business_Year int,
# Business_Month int,
# Business_Quarter int,
# Business_Week int
# )
# using DELTA
# PARTITIONED by (Business_Year)
# Out:
# StatementMeta(, f790f2fe-ddd7-4750-8b7f-5998e646fcf1, 4, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
start_date='2015-01-01'
end_date='2030-12-31'

date_diff=spark.sql("select date_diff('{}','{}')".format(end_date,start_date)).first()[0]
# Out:
# StatementMeta(, f790f2fe-ddd7-4750-8b7f-5998e646fcf1, 5, Finished, Available, Finished)

# %%
date_diff
# Out:
# StatementMeta(, f790f2fe-ddd7-4750-8b7f-5998e646fcf1, 6, Finished, Available, Finished)
# 5843

# %%
ID_Data=spark.range(0,date_diff)
# Out:
# StatementMeta(, f790f2fe-ddd7-4750-8b7f-5998e646fcf1, 7, Finished, Available, Finished)

# %%
date_data=ID_Data.selectExpr("date_add('{}',cast(id as int)) as BusinessDate".format(start_date))
# Out:
# StatementMeta(, f790f2fe-ddd7-4750-8b7f-5998e646fcf1, 8, Finished, Available, Finished)

# %%
date_data.createOrReplaceTempView("ViewDate")
# Out:
# StatementMeta(, f790f2fe-ddd7-4750-8b7f-5998e646fcf1, 9, Finished, Available, Finished)

# %%
# %%sql
#
# delete from Project_Lakehouse.gold_date;
# Out:
# StatementMeta(, f790f2fe-ddd7-4750-8b7f-5998e646fcf1, 10, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
# insert into Project_Lakehouse.gold_date
# select *,
# Year(BusinessDate) as Business_Year,
# Month(BusinessDate) as Business_Month,
# Quarter(BusinessDate) as Business_Quarter,
# weekday(BusinessDate) as Business_Week
#  from ViewDate
# Out:
# StatementMeta(, f790f2fe-ddd7-4750-8b7f-5998e646fcf1, 11, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>
