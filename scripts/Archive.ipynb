# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from notebookutils import mssparkutils
# Out:
# StatementMeta(, 2ea035cc-fc97-4b21-bc15-9e60bcf8ebb8, 9, Finished, Available, Finished)

# %%
mssparkutils.fs.mount("abfss://ffba5c1d-6c17-4857-92b8-283135916ea3@onelake.dfs.fabric.microsoft.com/2f70d0d4-b2dd-4276-a27c-dd99afb07eed/Files","/Files")
# Out:
# StatementMeta(, 2ea035cc-fc97-4b21-bc15-9e60bcf8ebb8, 10, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 1337df21-c314-4660-961e-31d995b6434e)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, 2ea035cc-fc97-4b21-bc15-9e60bcf8ebb8, 11, Finished, Available, Finished)
# '/synfs/notebook/2ea035cc-fc97-4b21-bc15-9e60bcf8ebb8/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/current/")

# %%
check_files
# Out:
# StatementMeta(, 2ea035cc-fc97-4b21-bc15-9e60bcf8ebb8, 28, Finished, Available, Finished)
# [FileInfo(path=file:/synfs/notebook/2ea035cc-fc97-4b21-bc15-9e60bcf8ebb8/Files/current/Sales_01012023.xlsx, name=Sales_01012023.xlsx, size=557795),
#  FileInfo(path=file:/synfs/notebook/2ea035cc-fc97-4b21-bc15-9e60bcf8ebb8/Files/current/Sales_02012023.xlsx, name=Sales_02012023.xlsx, size=498608)]

# %%
archive_path = f"file://{mssparkutils.fs.getMountPath('/Files')}/Archive/"


archive_files = mssparkutils.fs.ls(archive_path)


if len(archive_files) == 0:
    print("Aucun fichier trouvé dans le répertoire d'archive.")
else:
    
    for file in archive_files:
        print(file.path)
# Out:
# StatementMeta(, 2ea035cc-fc97-4b21-bc15-9e60bcf8ebb8, 20, Finished, Available, Finished)
# Aucun fichier trouvé dans le répertoire d'archive.

# %%
for file in check_files:
    if file.path:
        mssparkutils.fs.mv(file.path,f"file://{mssparkutils.fs.getMountPath('/Files')}/Archive/")
