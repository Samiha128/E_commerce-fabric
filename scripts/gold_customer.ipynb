# %%
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, 9ed5df69-04b3-405a-9afc-60e3f840dada, 3, Finished, Available, Finished)

# %%
# %%sql
# create table if not exists Project_Lakehouse.gold_Customer
# (
#   Customer_ID	string	,
# Customer_Name	string	,
# Segment	string	,
# City	string	,
# State	string	,
# Country	string	,
# Region	string	,
# Created_TS	timestamp	,
# Modified_TS	timestamp
#
# )
# using delta
# Out:
# StatementMeta(, 9ed5df69-04b3-405a-9afc-60e3f840dada, 4, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
Max_Date=spark.sql("""select coalesce(max(Modified_TS),"1900-01-01") from Project_Lakehouse.gold_Customer""").first()[0]
# Out:
# StatementMeta(, 9ed5df69-04b3-405a-9afc-60e3f840dada, 5, Finished, Available, Finished)

# %%
Max_Date
# Out:
# StatementMeta(, 9ed5df69-04b3-405a-9afc-60e3f840dada, 6, Finished, Available, Finished)
# '1900-01-01'

# %%
df_bronze=spark.read.table("Project_Lakehouse.bronze_sales")

df_final=df_bronze.selectExpr("Customer_ID","Customer_Name","Segment","City","State", \
                   "Country","Region")\
                   .where(col("Modified_TS")>Max_Date)\
                   .drop_duplicates()
# Out:
# StatementMeta(, 9ed5df69-04b3-405a-9afc-60e3f840dada, 7, Finished, Available, Finished)

# %%
df_final.createOrReplaceTempView("ViewCustomer")
# Out:
# StatementMeta(, 9ed5df69-04b3-405a-9afc-60e3f840dada, 8, Finished, Available, Finished)

# %%
# %%sql
# Merge into Project_lakehouse.gold_customer as gc
# using ViewCustomer as vc
# on gc.Customer_ID=vc.Customer_ID
# when matched then
# update set
# gc.Customer_Name	=	vc.Customer_Name	,
# gc.Segment	=	vc.Segment	,
# gc.City	=	vc.City	,
# gc.State	=	vc.State	,
# gc.Country	=	vc.Country	,
# gc.Region	=	vc.Region	,
# gc.Modified_TS	=	current_timestamp()
#
# when not matched then insert
# (
# gc.Customer_ID	,
# gc.Customer_Name	,
# gc.Segment	,
# gc.City	,
# gc.State	,
# gc.Country	,
# gc.Region	,
# gc.Created_TS	,
# gc.Modified_TS
# )
# values
# (
# vc.Customer_ID	,
# vc.Customer_Name	,
# vc.Segment	,
# vc.City	,
# vc.State	,
# vc.Country	,
# vc.Region	,
# current_timestamp(),
# current_timestamp
# )
# Out:
# StatementMeta(, 9ed5df69-04b3-405a-9afc-60e3f840dada, 10, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 4 fields>
